# %% [markdown]
# # Pre Processing Text collected
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import nltk
import string
import fasttext
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Accessing data collected

# %%
df = pd.read_csv('indeed_scrape.csv')
df
# Out:
#       Unnamed: 0  rating                                       rating_title  \
# 0              0     5.0                                  Fun Place to work
# 1              1     2.0                                    Poor Management
# 2              2     4.0                                 Fun place to work!
# 3              3     5.0                   Productive and fun place to work
# 4              4     1.0                                    No job security
# ...          ...     ...                                                ...
# 3124        3124     4.0                     Positive and fun place to work
# 3125        3125     4.0                    Lots of Professional Experience
# 3126        3126     4.0  Fun place to work, cool gear, local jobs prosp...
# 3127        3127     4.0                                 Nice place to work
# 3128        3128     5.0  very nice work culture, treated well , your op...
#
#                                      rating_description  \
# 0     Google has their own culture, what you see in ...
# 1     The team I work for is structured of people wi...
# 2     Fun place to work, but the industry can be com...
# 3     Definitely a great place to work. Loads of act...
# 4     Very bad local Management, they are not worth ...
# ...                                                 ...
# 3124  great supportive atmosphere. lots of opportuni...
# 3125  I learned the ethics working at such a competi...
# 3126  Great place to work, great peers,perks and man...
# 3127  I work as a contractor at Google. I was happy ...
# 3128  great atmosphere, work is to the point, good s...
#
#                                             rating_pros  \
# 0                 Free lunches, Lear alot, gBus commute
# 1                                                   NaN
# 2                                                   NaN
# 3                             The cafe and lounge areas
# 4                                    Better job outside
# ...                                                 ...
# 3124   free food, onsite gym, development opportunities
# 3125  Free lunches, free pickups and dropping, snack...
# 3126                                       Free lunches
# 3127                                                NaN
# 3128                   free breakfast, lunch, beverages
#
#                                             rating_cons
# 0                                               No cons
# 1                                                   NaN
# 2                                                   NaN
# 3                   For me, wasn't in my field of study
# 4     Do not work under INDIAN PEOPLE, They have the...
# ...                                                 ...
# 3124                                                NaN
# 3125                                                 Na
# 3126  hindered upward mobility for technical staff t...
# 3127                                                NaN
# 3128  only con is that it is difficult to be hired i...
#
# [3129 rows x 6 columns]

# %% [markdown]
# ## Removing unwanted columns

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#       rating                                       rating_title  \
# 0        5.0                                  Fun Place to work
# 1        2.0                                    Poor Management
# 2        4.0                                 Fun place to work!
# 3        5.0                   Productive and fun place to work
# 4        1.0                                    No job security
# ...      ...                                                ...
# 3124     4.0                     Positive and fun place to work
# 3125     4.0                    Lots of Professional Experience
# 3126     4.0  Fun place to work, cool gear, local jobs prosp...
# 3127     4.0                                 Nice place to work
# 3128     5.0  very nice work culture, treated well , your op...
#
#                                      rating_description  \
# 0     Google has their own culture, what you see in ...
# 1     The team I work for is structured of people wi...
# 2     Fun place to work, but the industry can be com...
# 3     Definitely a great place to work. Loads of act...
# 4     Very bad local Management, they are not worth ...
# ...                                                 ...
# 3124  great supportive atmosphere. lots of opportuni...
# 3125  I learned the ethics working at such a competi...
# 3126  Great place to work, great peers,perks and man...
# 3127  I work as a contractor at Google. I was happy ...
# 3128  great atmosphere, work is to the point, good s...
#
#                                             rating_pros  \
# 0                 Free lunches, Lear alot, gBus commute
# 1                                                   NaN
# 2                                                   NaN
# 3                             The cafe and lounge areas
# 4                                    Better job outside
# ...                                                 ...
# 3124   free food, onsite gym, development opportunities
# 3125  Free lunches, free pickups and dropping, snack...
# 3126                                       Free lunches
# 3127                                                NaN
# 3128                   free breakfast, lunch, beverages
#
#                                             rating_cons
# 0                                               No cons
# 1                                                   NaN
# 2                                                   NaN
# 3                   For me, wasn't in my field of study
# 4     Do not work under INDIAN PEOPLE, They have the...
# ...                                                 ...
# 3124                                                NaN
# 3125                                                 Na
# 3126  hindered upward mobility for technical staff t...
# 3127                                                NaN
# 3128  only con is that it is difficult to be hired i...
#
# [3129 rows x 5 columns]

# %% [markdown]
# ## Noting null values

# %%
for col in df.columns:
    print(col, df[col].isnull().sum())
# Out:
# rating 0
# rating_title 7
# rating_description 0
# rating_pros 1814
# rating_cons 1929

# %% [markdown]
# ## Expanding contractions

# %%
rws = df.loc[:, ['rating', 'rating_description']]
rws['no_contract'] = rws['rating_description'].apply(lambda x: [contractions.fix(word) for word in x.split()])
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...

# %% [markdown]
# ## Back to string

# %%
rws['rating_description_str'] = [' '.join(map(str, l)) for l in rws['no_contract']]
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str
# 0  Google has their own culture, what you see in ...
# 1  The team I work for is structured of people wi...
# 2  Fun place to work, but the industry can be com...
# 3  Definitely a great place to work. Loads of act...
# 4  Very bad local Management, they are not worth ...

# %% [markdown]
# ## Identifying english sentences only

# %%
pretrained_model = "lid.176.bin"
model = fasttext.load_model(pretrained_model)
langs = []
for sent in rws['rating_description_str']:
    lang = model.predict(sent)[0]
    langs.append(str(lang)[11:13])
rws['langs'] = langs
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
# ## Tokenization

# %%
rws['tokenized'] = rws['rating_description_str'].apply(word_tokenize)
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...

# %% [markdown]
# ## lowercasing

# %%
rws['lower'] = rws['tokenized'].apply(lambda x: [word.lower() for word in x])
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized  \
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...
#
#                                                lower
# 0  [google, has, their, own, culture, ,, what, yo...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, ,, but, the, industry, ...
# 3  [definitely, a, great, place, to, work, ., loa...
# 4  [very, bad, local, management, ,, they, are, n...

# %% [markdown]
# ## removing punctuation marks

# %%
punc = string.punctuation
rws['no_punc'] = rws['lower'].apply(lambda x: [word for word in x if word not in punc])
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized  \
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...
#
#                                                lower  \
# 0  [google, has, their, own, culture, ,, what, yo...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, ,, but, the, industry, ...
# 3  [definitely, a, great, place, to, work, ., loa...
# 4  [very, bad, local, management, ,, they, are, n...
#
#                                              no_punc
# 0  [google, has, their, own, culture, what, you, ...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, but, the, industry, can...
# 3  [definitely, a, great, place, to, work, loads,...
# 4  [very, bad, local, management, they, are, not,...

# %% [markdown]
# ## Removing stopwords

# %%
stop_words = set(stopwords.words('english'))
rws['stopwords_removed'] = rws['no_punc'].apply(lambda x: [word for word in x if word not in stop_words])
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized  \
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...
#
#                                                lower  \
# 0  [google, has, their, own, culture, ,, what, yo...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, ,, but, the, industry, ...
# 3  [definitely, a, great, place, to, work, ., loa...
# 4  [very, bad, local, management, ,, they, are, n...
#
#                                              no_punc  \
# 0  [google, has, their, own, culture, what, you, ...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, but, the, industry, can...
# 3  [definitely, a, great, place, to, work, loads,...
# 4  [very, bad, local, management, they, are, not,...
#
#                                    stopwords_removed
# 0  [google, culture, see, companies, organization...
# 1  [team, work, structured, people, poor, working...
# 2  [fun, place, work, industry, complex, dependin...
# 3  [definitely, great, place, work, loads, activi...
# 4  [bad, local, management, worth, act, like, org...

# %% [markdown]
# ## POS tagging

# %%
rws['pos_tags'] = rws['stopwords_removed'].apply(nltk.tag.pos_tag)
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized  \
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...
#
#                                                lower  \
# 0  [google, has, their, own, culture, ,, what, yo...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, ,, but, the, industry, ...
# 3  [definitely, a, great, place, to, work, ., loa...
# 4  [very, bad, local, management, ,, they, are, n...
#
#                                              no_punc  \
# 0  [google, has, their, own, culture, what, you, ...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, but, the, industry, can...
# 3  [definitely, a, great, place, to, work, loads,...
# 4  [very, bad, local, management, they, are, not,...
#
#                                    stopwords_removed  \
# 0  [google, culture, see, companies, organization...
# 1  [team, work, structured, people, poor, working...
# 2  [fun, place, work, industry, complex, dependin...
# 3  [definitely, great, place, work, loads, activi...
# 4  [bad, local, management, worth, act, like, org...
#
#                                             pos_tags
# 0  [(google, JJ), (culture, NN), (see, NN), (comp...
# 1  [(team, NN), (work, NN), (structured, VBD), (p...
# 2  [(fun, NN), (place, NN), (work, NN), (industry...
# 3  [(definitely, RB), (great, JJ), (place, NN), (...
# 4  [(bad, JJ), (local, JJ), (management, NN), (wo...

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

rws['wordnet_pos'] = rws['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized  \
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...
#
#                                                lower  \
# 0  [google, has, their, own, culture, ,, what, yo...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, ,, but, the, industry, ...
# 3  [definitely, a, great, place, to, work, ., loa...
# 4  [very, bad, local, management, ,, they, are, n...
#
#                                              no_punc  \
# 0  [google, has, their, own, culture, what, you, ...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, but, the, industry, can...
# 3  [definitely, a, great, place, to, work, loads,...
# 4  [very, bad, local, management, they, are, not,...
#
#                                    stopwords_removed  \
# 0  [google, culture, see, companies, organization...
# 1  [team, work, structured, people, poor, working...
# 2  [fun, place, work, industry, complex, dependin...
# 3  [definitely, great, place, work, loads, activi...
# 4  [bad, local, management, worth, act, like, org...
#
#                                             pos_tags  \
# 0  [(google, JJ), (culture, NN), (see, NN), (comp...
# 1  [(team, NN), (work, NN), (structured, VBD), (p...
# 2  [(fun, NN), (place, NN), (work, NN), (industry...
# 3  [(definitely, RB), (great, JJ), (place, NN), (...
# 4  [(bad, JJ), (local, JJ), (management, NN), (wo...
#
#                                          wordnet_pos
# 0  [(google, a), (culture, n), (see, n), (compani...
# 1  [(team, n), (work, n), (structured, v), (peopl...
# 2  [(fun, n), (place, n), (work, n), (industry, n...
# 3  [(definitely, r), (great, a), (place, n), (wor...
# 4  [(bad, a), (local, a), (management, n), (worth...

# %% [markdown]
# ## Lemmatization

# %%
wnl = WordNetLemmatizer()
rws['lemmatized'] = rws['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])
rws.head()
# Out:
#    rating                                 rating_description  \
# 0     5.0  Google has their own culture, what you see in ...
# 1     2.0  The team I work for is structured of people wi...
# 2     4.0  Fun place to work, but the industry can be com...
# 3     5.0  Definitely a great place to work. Loads of act...
# 4     1.0  Very bad local Management, they are not worth ...
#
#                                          no_contract  \
# 0  [Google, has, their, own, culture,, what, you,...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work,, but, the, industry, ca...
# 3  [Definitely, a, great, place, to, work., Loads...
# 4  [Very, bad, local, Management,, they, are, not...
#
#                               rating_description_str langs  \
# 0  Google has their own culture, what you see in ...    en
# 1  The team I work for is structured of people wi...    en
# 2  Fun place to work, but the industry can be com...    en
# 3  Definitely a great place to work. Loads of act...    en
# 4  Very bad local Management, they are not worth ...    en
#
#                                            tokenized  \
# 0  [Google, has, their, own, culture, ,, what, yo...
# 1  [The, team, I, work, for, is, structured, of, ...
# 2  [Fun, place, to, work, ,, but, the, industry, ...
# 3  [Definitely, a, great, place, to, work, ., Loa...
# 4  [Very, bad, local, Management, ,, they, are, n...
#
#                                                lower  \
# 0  [google, has, their, own, culture, ,, what, yo...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, ,, but, the, industry, ...
# 3  [definitely, a, great, place, to, work, ., loa...
# 4  [very, bad, local, management, ,, they, are, n...
#
#                                              no_punc  \
# 0  [google, has, their, own, culture, what, you, ...
# 1  [the, team, i, work, for, is, structured, of, ...
# 2  [fun, place, to, work, but, the, industry, can...
# 3  [definitely, a, great, place, to, work, loads,...
# 4  [very, bad, local, management, they, are, not,...
#
#                                    stopwords_removed  \
# 0  [google, culture, see, companies, organization...
# 1  [team, work, structured, people, poor, working...
# 2  [fun, place, work, industry, complex, dependin...
# 3  [definitely, great, place, work, loads, activi...
# 4  [bad, local, management, worth, act, like, org...
#
#                                             pos_tags  \
# 0  [(google, JJ), (culture, NN), (see, NN), (comp...
# 1  [(team, NN), (work, NN), (structured, VBD), (p...
# 2  [(fun, NN), (place, NN), (work, NN), (industry...
# 3  [(definitely, RB), (great, JJ), (place, NN), (...
# 4  [(bad, JJ), (local, JJ), (management, NN), (wo...
#
#                                          wordnet_pos  \
# 0  [(google, a), (culture, n), (see, n), (compani...
# 1  [(team, n), (work, n), (structured, v), (peopl...
# 2  [(fun, n), (place, n), (work, n), (industry, n...
# 3  [(definitely, r), (great, a), (place, n), (wor...
# 4  [(bad, a), (local, a), (management, n), (worth...
#
#                                           lemmatized
# 0  [google, culture, see, company, organizations,...
# 1  [team, work, structure, people, poor, work, ex...
# 2  [fun, place, work, industry, complex, dependin...
# 3  [definitely, great, place, work, load, activit...
# 4  [bad, local, management, worth, act, like, org...

# %% [markdown]
# ## Saving data for future use

# %%
rws.to_csv('indeed_scrape_clean.csv')
