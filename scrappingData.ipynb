# %% [markdown]
# # Scrapping Data from Web for NLP
# ## Importing libraries

# %%
from bs4 import BeautifulSoup
import lxml
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ## Lets go through website we want to scrap data from

# %%
base_url = requests.get('https://www.indeed.com/cmp/Google/reviews', timeout=5)
base_url.text
# Out:
# '<!doctype html><html lang="en"><head><title>Working at Google in Noida, Uttar Pradesh: Employee Reviews | Indeed.com</title><meta http-equiv="content-type" content="text/html;charset=UTF-8"><meta name="description" content="Reviews from Google employees about Google culture, salaries, benefits, work-life balance, management, job security, and more."><meta name="viewport" content="width=device-width, initial-scale=1"><link rel="canonical" href="https://www.indeed.co.in/cmp/Google/reviews?fcountry=IN&amp;floc=Noida%2C+Uttar+Pradesh"><link rel="stylesheet" type="text/css" href="/cmp/_s/s/3cb7454/global.css" ><link rel="stylesheet" type="text/css" href="/cmp/_s/w/50c52677e90563f526e2/css/vendor.css" ><link rel="stylesheet" type="text/css" href="/cmp/_s/w/ec604737d8896895d2f1/css/reviews-client.css" ><link rel="icon" href="/images/favicon.ico"><script type="text/javascript">window.__JSERROR__=[];window.onerror=function() { window.__JSERROR__.push(arguments)}</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,document,\'script\',\'dataLayer\',\'GTM-5BCKBTQ\');</script></head><body><noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-5BCKBTQ" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><style type="text/css">\n            body { margin-top: 0; margin-left: 0; margin-right: 0; padding-top: 0; padding-right: 0; padding-left: 0; }\n            </style><script type="text/javascript" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/ecd41dd9c7a157f8d666/scripts/shim.js"></script><link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/3f57cb22c47a12b61a76/styles/index.css" />\n<div dir="ltr"><script id="_indeed_gnav_config" type="application/json">{"isEmployer":false,"primaryURL":"https://www.indeed.com/","requestURL":"www.indeed.com/cmp/Google/reviews","from":"gnav-menu-acme--acme-webapp","isShowSmallHeader":true,"logClickTracking":true,"desktopPageLinks":[{"text":"Find jobs","href":"https://www.indeed.com/","dataHref":"https://www.indeed.com/?from=gnav-acme--acme-webapp","isHighlighted":false,"clickTrackingKey":"Find Jobs"},{"text":"Company reviews","href":"https://www.indeed.com/companies","dataHref":"https://www.indeed.com/companies?from=gnav-acme--acme-webapp","isHighlighted":true,"clickTrackingKey":"Company Reviews"},{"text":"Find salaries","href":"https://www.indeed.com/salaries","dataHref":"https://www.indeed.com/salaries?from=gnav-acme--acme-webapp","isHighlighted":false,"clickTrackingKey":"Find Salaries"}],"resumeLink":{"text":"Upload your resume","href":"https://www.indeed.com/promo/resume","dataHref":"https://www.indeed.com/promo/resume?from=gnav-acme--acme-webapp","isHighlighted":false},"variantToggleLink":{"text":"Employers / Post Job","href":"https://www.indeed.com/hire?co=US\\u0026hl=en","dataHref":"https://www.indeed.com/hire?co=US\\u0026hl=en\\u0026from=gnav-menu-acme--acme-webapp\\u0026ikw=gnav-header-hire\\u0026isid=employerlink-US","clickTrackingKey":"EmployersPostJob"},"country":"US","logoHref":"https://www.indeed.com?from=gnav-acme--acme-webapp","logoName":"","appName":"acme--acme-webapp","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-acme--acme-webapp\\u0026gnavTK=1efbmssitol95800\\u0026tk=\\u0026co=US\\u0026hl=en\\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-acme--acme-webapp\\u0026gnavTK=1efbmssitol95800\\u0026tk=\\u0026co=US\\u0026hl=en","logRoute":"https://t.indeed.com/gnav/log?from=acme--acme-webapp-%2Fcmp%2FGoogle%2Freviews\\u0026parentLogId=1efbmssitol95800\\u0026hostAppTk=","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isInboxTestActive":false,"isShowInboxIco ...

# %% [markdown]
# ## Parsing a url

# %%
def parse(full_url):
    page_content = BeautifulSoup(full_url.content, 'lxml')
    containers = page_content.findAll('div', {'class':'cmp-Review-container'})
    df = pd.DataFrame(columns = ['rating', 'rating_title',  'rating_description', 'rating_pros', 'rating_cons'])
    
    for item in containers:
        try:
            rating = item.find('div', {'class': 'cmp-ReviewRating-text'}).text.replace('\n', '')
        except:
            rating = None
        try:
            rating_title = item.find('div', {'class': 'cmp-Review-title'}).text.replace('\n', '')
        except:
            rating_title = None
        try:
            rating_description = item.find('span', {'itemprop': 'reviewBody'}).text.replace('\r', '. ')
        except:
            rating_description = None
        try:
            rating_pros = item.find('div', {'class': 'cmp-ReviewProsCons-prosText'}).text.replace('\n', '')
        except:
            rating_pros = None
        try:
            rating_cons = item.find('div', {'class': 'cmp-ReviewProsCons-consText'}).text.replace('\n', '')
        except:
            rating_cons = None
        df = df.append({'rating': rating, 
             'rating_title': rating_title, 
             'rating_description': rating_description,
             'rating_pros': rating_pros, 
             'rating_cons': rating_cons}, ignore_index=True)
    return df

# %% [markdown]
# ## Define overall Dataframe

# %%
base_url = 'https://www.indeed.com/cmp/Google/reviews?fcountry=ALL&start='
all_reviews_df = pd.DataFrame(columns = ['rating', 'rating_title', 'rating_description','rating_pros', 'rating_cons'])
num_reviews = 20 # you can adjust this number on how many reviews you which to scrape

# %% [markdown]
# ## Iterate over all the pages

# %%
while num_reviews < 3000:
    print("collecting reviews: "+str(num_reviews))
    full_url = base_url + str(num_reviews)

    get_url = requests.get(full_url, timeout=5)

    partial_reviews_df = parse(get_url)    

    all_reviews_df = all_reviews_df.append(partial_reviews_df, ignore_index=True)

    num_reviews += 20
# Out:
# collecting reviews: 20
# collecting reviews: 40
# collecting reviews: 60
# collecting reviews: 80
# collecting reviews: 100
# collecting reviews: 120
# collecting reviews: 140
# collecting reviews: 160
# collecting reviews: 180
# collecting reviews: 200
# collecting reviews: 220
# collecting reviews: 240
# collecting reviews: 260
# collecting reviews: 280
# collecting reviews: 300
# collecting reviews: 320
# collecting reviews: 340
# collecting reviews: 360
# collecting reviews: 380
# collecting reviews: 400
# collecting reviews: 420
# collecting reviews: 440
# collecting reviews: 460
# collecting reviews: 480
# collecting reviews: 500
# collecting reviews: 520
# collecting reviews: 540
# collecting reviews: 560
# collecting reviews: 580
# collecting reviews: 600
# collecting reviews: 620
# collecting reviews: 640
# collecting reviews: 660
# collecting reviews: 680
# collecting reviews: 700
# collecting reviews: 720
# collecting reviews: 740
# collecting reviews: 760
# collecting reviews: 780
# collecting reviews: 800
# collecting reviews: 820
# collecting reviews: 840
# collecting reviews: 860
# collecting reviews: 880
# collecting reviews: 900
# collecting reviews: 920
# collecting reviews: 940
# collecting reviews: 960
# collecting reviews: 980
# collecting reviews: 1000
# collecting reviews: 1020
# collecting reviews: 1040
# collecting reviews: 1060
# collecting reviews: 1080
# collecting reviews: 1100
# collecting reviews: 1120
# collecting reviews: 1140
# collecting reviews: 1160
# collecting reviews: 1180
# collecting reviews: 1200
# collecting reviews: 1220
# collecting reviews: 1240
# collecting reviews: 1260
# collecting reviews: 1280
# collecting reviews: 1300
# collecting reviews: 1320
# collecting reviews: 1340
# collecting reviews: 1360
# collecting reviews: 1380
# collecting reviews: 1400
# collecting reviews: 1420
# collecting reviews: 1440
# collecting reviews: 1460
# collecting reviews: 1480
# collecting reviews: 1500
# collecting reviews: 1520
# collecting reviews: 1540
# collecting reviews: 1560
# collecting reviews: 1580
# collecting reviews: 1600
# collecting reviews: 1620
# collecting reviews: 1640
# collecting reviews: 1660
# collecting reviews: 1680
# collecting reviews: 1700
# collecting reviews: 1720
# collecting reviews: 1740
# collecting reviews: 1760
# collecting reviews: 1780
# collecting reviews: 1800
# collecting reviews: 1820
# collecting reviews: 1840
# collecting reviews: 1860
# collecting reviews: 1880
# collecting reviews: 1900
# collecting reviews: 1920
# collecting reviews: 1940
# collecting reviews: 1960
# collecting reviews: 1980
# collecting reviews: 2000
# collecting reviews: 2020
# collecting reviews: 2040
# collecting reviews: 2060
# collecting reviews: 2080
# collecting reviews: 2100
# collecting reviews: 2120
# collecting reviews: 2140
# collecting reviews: 2160
# collecting reviews: 2180
# collecting reviews: 2200
# collecting reviews: 2220
# collecting reviews: 2240
# collecting reviews: 2260
# collecting reviews: 2280
# collecting reviews: 2300
# collecting reviews: 2320
# collecting reviews: 2340
# collecting reviews: 2360
# collecting reviews: 2380
# collecting reviews: 2400
# collecting reviews: 2420
# collecting reviews: 2440
# collecting reviews: 2460
# collecting reviews: 2480
# collecting reviews: 2500
# collecting reviews: 2520
# collecting reviews: 2540
# collecting reviews: 2560
# collecting reviews: 2580
# collecting reviews: 2600
# collecting reviews: 2620
# collecting reviews: 2640
# collecting reviews: 2660
# collecting reviews: 2680
# collecting reviews: 2700
# collecting reviews: 2720
# collecting reviews: 2740
# collecting reviews: 2760
# collecting reviews: 2780
# collecting reviews: 2800
# collecting reviews: 2820
# collecting reviews: 2840
# collecting reviews: 2860
# collecting reviews: 2880
# collecting reviews: 2900
# collecting reviews: 2920
# collecting reviews: 2940
# collecting reviews: 2960
# collecting reviews: 2980

# %% [markdown]
# ## Check the data collected

# %%
all_reviews_df
# Out:
#      rating                                       rating_title  \
# 0       5.0                                  Fun Place to work
# 1       2.0                                    Poor Management
# 2       4.0                                 Fun place to work!
# 3       5.0                   Productive and fun place to work
# 4       1.0                                    No job security
# ...     ...                                                ...
# 3124    4.0                     Positive and fun place to work
# 3125    4.0                    Lots of Professional Experience
# 3126    4.0  Fun place to work, cool gear, local jobs prosp...
# 3127    4.0                                 Nice place to work
# 3128    5.0  very nice work culture, treated well , your op...
#
#                                      rating_description  \
# 0     Google has their own culture, what you see in ...
# 1     The team I work for is structured of people wi...
# 2     Fun place to work, but the industry can be com...
# 3     Definitely a great place to work. Loads of act...
# 4     Very bad local Management, they are not worth ...
# ...                                                 ...
# 3124  great supportive atmosphere. lots of opportuni...
# 3125  I learned the ethics working at such a competi...
# 3126  Great place to work, great peers,perks and man...
# 3127  I work as a contractor at Google. I was happy ...
# 3128  great atmosphere, work is to the point, good s...
#
#                                             rating_pros  \
# 0                 Free lunches, Lear alot, gBus commute
# 1                                                  None
# 2                                                  None
# 3                             The cafe and lounge areas
# 4                                    Better job outside
# ...                                                 ...
# 3124   free food, onsite gym, development opportunities
# 3125  Free lunches, free pickups and dropping, snack...
# 3126                                       Free lunches
# 3127                                               None
# 3128                   free breakfast, lunch, beverages
#
#                                             rating_cons
# 0                                               No cons
# 1                                                  None
# 2                                                  None
# 3                   For me, wasn't in my field of study
# 4     Do not work under INDIAN PEOPLE, They have the...
# ...                                                 ...
# 3124                                               None
# 3125                                                 Na
# 3126  hindered upward mobility for technical staff t...
# 3127                                               None
# 3128  only con is that it is difficult to be hired i...
#
# [3129 rows x 5 columns]

# %% [markdown]
# ## Save data for future use

# %%
all_reviews_df.to_csv('indeed_scrape.csv')
